# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# ''

# %%
s = "this is nice way to learn data science"

# %%
f.close()

# %%
f = open("deepali.txt","w")

# %%
f.write(s)
# Out:
# 38

# %%
f.close()
