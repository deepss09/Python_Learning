# %%
a = 11
b = 5

# %%
a+b
# Out:
# 16

# %%
a*b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2***5
# Out:
#   Cell In[12], line 1
#     2***5
#        ^
# SyntaxError: invalid syntax

# %%
2**5
# Out:
# 32

# %%
a%b
# Out:
# 1

# %%
a = 45

# %%
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a = b

# %%
a == c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a == c
#
# NameError: name 'c' is not defined

# %%
a != c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 a != c
#
# NameError: name 'c' is not defined
