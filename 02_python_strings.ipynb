# %%
name = "deepali"

# %%
name
# Out:
# 'deepali'

# %%
name.upper()
# Out:
# 'DEEPALI'

# %%
name.endswith("ry")
# Out:
# False

# %%
name.endswith("li")
# Out:
# True

# %%
name.lower()
# Out:
# 'deepali'

# %%
name.count("a)
# Out:
#   Cell In[7], line 1
#     name.count("a)
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name.count("a")
# Out:
# 1

# %%
s = "deepali"
print(len(s))
# Out:
# 7

# %%
s[1:-1]
# Out:
# 'eepal'

# %%
s[1:12]
# Out:
# 'eepali'
