# %%
s = "Deepali"

# %%
s[0] = 'p'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s[0] = 'p'
#
# TypeError: 'str' object does not support item assignment

# %%
s.upper()
# Out:
# 'DEEPALI'
