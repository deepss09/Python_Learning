# %%
a = input ("Enter the value of a") #by default default it take user input as string
# Out:
# Enter the value of a 11

# %%
a
# Out:
# '11'

# %%
b = input ("enter the value of b")
# Out:
# enter the value of b 65

# %%
b
# Out:
# '65'

# %%
a+b
# Out:
# '1165'

# %%
int (a) + int (b)
# Out:
# 76

# %%
c = input()
# Out:
#  12
