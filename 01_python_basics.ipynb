# %%
a = 5

# %%
b = 32

# %%
a+b
# Out:
# 37

# %%
name = "harry"

# %%
print("Hello world")
# Out:
# Hello world

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(name)
# Out:
# str

# %%
a = "4566"

# %%
b = "5633"

# %%
print(a+b)
# Out:
# 45665633

# %%
int (a) + int (b)
# Out:
# 10199
