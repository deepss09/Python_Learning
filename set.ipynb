# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
b = {4,3,6,2,66,4}

# %%
b = {4,3,66,12,90}

# %%
b.update(4,64,34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 b.update(4,64,34)
#
# TypeError: 'int' object is not iterable

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set1.intersection(set2)
# Out:
# {3, 4}
